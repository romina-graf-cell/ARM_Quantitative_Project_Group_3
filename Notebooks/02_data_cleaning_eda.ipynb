# %% [markdown]
# # 02 - Data Cleaning & Exploratory Data Analysis (EDA)
# This notebook loads the raw data from SQLite, cleans it, enriches it with construction-period catgeories, and performs exploratory data analysis.
#
# We proceed in four stages:
# 1. Load raw data from SQLite
# 2. Clean and standardize scraped variables
# 3. Map listings to BFS Bauperiode categories
# 4. Compute derived variables and perform EDA

# %% [markdown]
# # Load Raw Data
# We load:
# - BFS construction period categories
# - Raw scraped rental listings
# from the SQLite database created in Notebook 01

# %%
import pandas as pd
import sqlite3

conn = sqlite3.connect("../Data/apartment_database.db")

df_bauperiode = pd.read_sql("SELECT * FROM bfs_bauperiode_categories", conn)
df_raw = pd.read_sql("SELECT * FROM rental_listings_raw", conn)

conn.close()

df_raw.head()
# Out:
#   web_scraper_order  id                              web_scraper_start_url  \
# 0      1764272678-4   1  https://www.homegate.ch/rent/real-estate/city-...
# 1      1764272681-5   2  https://www.homegate.ch/rent/real-estate/city-...
# 2      1764272684-6   3  https://www.homegate.ch/rent/real-estate/city-...
# 3      1764272687-7   4  https://www.homegate.ch/rent/real-estate/city-...
# 4     1764272699-10   5  https://www.homegate.ch/rent/real-estate/city-...
#
#                                           link_pages  \
# 0  https://www.homegate.ch/rent/real-estate/city-...
# 1  https://www.homegate.ch/rent/real-estate/city-...
# 2  https://www.homegate.ch/rent/real-estate/city-...
# 3  https://www.homegate.ch/rent/real-estate/city-...
# 4  https://www.homegate.ch/rent/real-estate/city-...
#
#                              link_listings area_m2_raw  area_m2  rooms_raw  \
# 0  https://www.homegate.ch/rent/4002530569      134 m2      134        5.5
# 1  https://www.homegate.ch/rent/4002542635       98 m2       98        3.5
# 2  https://www.homegate.ch/rent/4002551340       68 m2       68        3.5
# 3  https://www.homegate.ch/rent/4002567338      134 m2      134        5.5
# 4  https://www.homegate.ch/rent/4002572292       94 m2       94        4.5
#
#   rent_chf_raw  rent_chf  year_built_raw  \
# 0      2,530.–      2530            1984
# 1      2,255.–      2255            1989
# 2      1,945.–      1945            1973
# 3      5,590.–      5590            1906
# 4      2,360.–      2360            1971
#
#                                  address  canton
# 0      Kesslernmattstr. 14, 8965 Berikon  Zurich
# 1            Im Spitzler 21, 8902 Urdorf  Zurich
# 2  Ferdinand Hodler-Str. 14, 8049 Zürich  Zurich
# 3        Weinbergstrasse 72, 8006 Zürich  Zurich
# 4      Bahnhofstr. 73, 8957 Spreitenbach  Zurich

# %% [markdown]
# # Inspect & Understand Raw Data
# We examine the structure of the raw scraped data to plan the cleaning steps

# %%
df_raw.info()
df_raw.head(10)
df_raw.describe(include="all")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   web_scraper_order      120 non-null    object
#  1   id                     120 non-null    int64
#  2   web_scraper_start_url  120 non-null    object
#  3   link_pages             120 non-null    object
#  4   link_listings          120 non-null    object
#  5   area_m2_raw            120 non-null    object
#  6   area_m2                120 non-null    int64
#  7   rooms_raw              120 non-null    float64
#  8   rent_chf_raw           120 non-null    object
#  9   rent_chf               120 non-null    int64
#  10  year_built_raw         120 non-null    int64
#  11  address                120 non-null    object
#  12  canton                 120 non-null    object
# dtypes: float64(1), int64(4), object(8)
# memory usage: 12.3+ KB
#        web_scraper_order          id  \
# count                120  120.000000
# unique               120         NaN
# top         1764272678-4         NaN
# freq                   1         NaN
# mean                 NaN   60.500000
# std                  NaN   34.785054
# min                  NaN    1.000000
# 25%                  NaN   30.750000
# 50%                  NaN   60.500000
# 75%                  NaN   90.250000
# max                  NaN  120.000000
#
#                                     web_scraper_start_url  \
# count                                                 120
# unique                                                  5
# top     https://www.homegate.ch/rent/real-estate/city-...
# freq                                                   40
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                link_pages  \
# count                                                 120
# unique                                                 10
# top     https://www.homegate.ch/rent/real-estate/canto...
# freq                                                   20
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                   link_listings area_m2_raw     area_m2  \
# count                                       120         120  120.000000
# unique                                      120          59         NaN
# top     https://www.homegate.ch/rent/4002530569       70 m2         NaN
# freq                                          1           6         NaN
# mean                                        NaN         NaN   90.191667
# std                                         NaN         NaN   25.034194
# min                                         NaN         NaN   40.000000
# 25%                                         NaN         NaN   71.000000
# 50%                                         NaN         NaN   86.000000
# 75%                                         NaN         NaN  102.000000
# max                                         NaN         NaN  193.000000
#
#          rooms_raw rent_chf_raw    rent_chf  year_built_raw  \
# count   120.000000          120   120.00000      120.000000
# unique         NaN          102         NaN             NaN
# top            NaN      2,860.–         NaN             NaN
# freq           NaN            2         NaN             NaN
# mean      3.654167          NaN  2599.97500     1989.466667
# std       0.774585          NaN  1037.84266       31.661533
# min       2.500000          NaN  1180.00000     1890.000000
# 25%       3.500000          NaN  1800.00000     1964.750000
# 50%       3.500000          NaN  2277.50000     1994.000000
# 75%       4.500000          NaN  3027.50000     2016.500000
# max       5.500000          NaN  7350.00000     2025.000000
#
#                            address  canton
# count                          120     120
# unique                         110       3
# top     Stuckweg 4, 8305 Dietlikon  Zurich
# freq                             2      40
# mean                           NaN     NaN
# std                            NaN     NaN
# min                            NaN     NaN
# 25%                            NaN     NaN
# 50%                            NaN     NaN
# 75%                            NaN     NaN
# max                            NaN     NaN

# %% [markdown]
# # Clean Numerical Fields
# We clean:
# - rent (CHF)
# - area (m2)
# - rooms
# Convert string values (e.g., "1'900.-") to numeric.
